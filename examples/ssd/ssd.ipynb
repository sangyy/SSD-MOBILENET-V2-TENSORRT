# %% [markdown]
# # TLT SSD example usecase
#
# This notebook shows an example usecase of SSD object detection using Transfer Learning Toolkit.
#
# 0. [Set up env variables](#head-0)
# 1. [Prepare dataset and pre-trained model](#head-1) <br>
#     1.1 [Prepare tfrecords from kitti format dataset](#head-1-1) <br>
#     1.2 [Download pre-trained model](#head-1-2) <br>
# 2. [Provide training specification](#head-2)
# 3. [Run TLT training](#head-3)
# 4. [Evaluate trained models](#head-4)
# 5. [Prune trained models](#head-5)
# 6. [Retrain pruned models](#head-6)
# 7. [Evaluate retrained model](#head-7)
# 8. [Visualize inferences](#head-8)
# 9. [Deploy](#head-9)
# 10. [Verify deployed model](#head-10)

# %% [markdown]
# ## 0. Set up env variables <a class="anchor" id="head-0"></a>

# %%
# Setting up env variables for cleaner command line commands.
print("Please replace the variable with your key.")
# %set_env KEY=OHB1YTZ0Z2RxYTBzdnE3YTNpcnVydmM4cXI6OGVkNDU4ZGQtNjViOC00NzYxLWFhMDUtMjgxMDQ2ZTVmNzAx
# %set_env USER_EXPERIMENT_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano
# %set_env DATA_DOWNLOAD_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data
# %set_env SPECS_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/specs
# !mkdir -p $USER_EXPERIMENT_DIR
# !mkdir -p $DATA_DOWNLOAD_DIR
# !mkdir -p $SPECS_DIR
# Out:
# Please replace the variable with your key.
# env: KEY=OHB1YTZ0Z2RxYTBzdnE3YTNpcnVydmM4cXI6OGVkNDU4ZGQtNjViOC00NzYxLWFhMDUtMjgxMDQ2ZTVmNzAx
# env: USER_EXPERIMENT_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano
# env: DATA_DOWNLOAD_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data
# env: SPECS_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/specs

# %% [markdown]
# ## 1. Prepare dataset and pre-trained model <a class="anchor" id="head-1"></a>

# %% [markdown]
#  We will be using the KITTI detection dataset for the tutorial. To find more details please visit
#  http://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=2d. Please download the KITTI detection images (http://www.cvlibs.net/download.php?file=data_object_image_2.zip) and labels (http://www.cvlibs.net/download.php?file=data_object_label_2.zip) to $DATA_DOWNLOAD_DIR.

# %%
# Check the dataset is present
# !mkdir -p $DATA_DOWNLOAD_DIR
# !if [ ! -f $DATA_DOWNLOAD_DIR/data_object_image_2.zip ]; then echo 'Image zip file not found, please download.'; else echo 'Found Image zip file.';fi
# !if [ ! -f $DATA_DOWNLOAD_DIR/data_object_label_2.zip ]; then echo 'Label zip file not found, please download.'; else echo 'Found Labels zip file.';fi
# Out:
# Found Image zip file.
# Found Labels zip file.

# %%
# unpack 
# !unzip -u $DATA_DOWNLOAD_DIR/data_object_image_2.zip -d $DATA_DOWNLOAD_DIR
# !unzip -u $DATA_DOWNLOAD_DIR/data_object_label_2.zip -d $DATA_DOWNLOAD_DIR

# %%
# verify
# !ls -l $DATA_DOWNLOAD_DIR/
# Out:
# total 12280824
# -rwxrwxrwx 1 1000 1000 12569945557 Jun 28 05:00 data_object_image_2.zip
# -rw-r--r-- 1 root root     5601213 May 11  2018 data_object_label_2.zip
# drwxr-xr-x 3 root root        4096 Jun 28 09:15 testing
# drwxr-xr-x 4 root root        4096 Jun 28 10:58 training

# %% [markdown]
# Additionally, if you have your own dataset already in a volume (or folder), you can mount the volume on `DATA_DOWNLOAD_DIR` (or create a soft link). Below shows an example:
# ```bash
# # if your dataset is in /dev/sdc1
# mount /dev/sdc1 $DATA_DOWNLOAD_DIR
#
# # if your dataset is in folder /var/dataset
# ln -sf /var/dataset $DATA_DOWNLOAD_DIR
# ```

# %% [markdown]
# ### 1.1 Prepare tfrecords from kitti format dataset <a class="anchor" id="head-1-1"></a>
#
# * Update the tfrecords spec file to take in your kitti format dataset
# * Create the tfrecords using the tlt-dataset-convert
# * TFRecords only need to be generated once.

# %%
print("TFrecords conversion spec file for training")
# !cat $SPECS_DIR/ssd_tfrecords_kitti_trainval.txt
# Out:
# TFrecords conversion spec file for training
# kitti_config {
#   root_directory_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training"
#   image_dir_name: "image_2"
#   label_dir_name: "label_2"
#   image_extension: ".png"
#   partition_mode: "random"
#   num_partitions: 2
#   val_split: 14
#   num_shards: 10
# }
# image_directory_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training"

# %%
# Creating a new directory for the output tfrecords dump.
# !mkdir -p $USER_EXPERIMENT_DIR/tfrecords
#KITTI trainval
# !tlt-dataset-convert -d $SPECS_DIR/ssd_tfrecords_kitti_trainval.txt \
                     -o $DATA_DOWNLOAD_DIR/tfrecords/kitti_trainval/kitti_trainval
# Out:
# Using TensorFlow backend.
# 2020-06-28 12:01:16,152 - iva.detectnet_v2.dataio.build_converter - INFO - Instantiating a kitti converter
# 2020-06-28 12:01:16,152 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Creating output directory /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/tfrecords/kitti_trainval
# 2020-06-28 12:01:16,174 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Num images in
# Train: 6434	Val: 1047
# 2020-06-28 12:01:16,174 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2020-06-28 12:01:16,176 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 0
# /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/dataio/kitti_converter_lib.py:266: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 2020-06-28 12:01:16,287 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 1
# 2020-06-28 12:01:16,390 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 2
# 2020-06-28 12:01:16,492 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 3
# 2020-06-28 12:01:16,591 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 4
# 2020-06-28 12:01:16,690 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 5
# 2020-06-28 12:01:16,792 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 6
# 2020-06-28 12:01:16,892 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 7
# 2020-06-28 12:01:16,992 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 8
# 2020-06-28 12:01:17,091 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 9
# 2020-06-28 12:01:17,199 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# cyclist: 252
# van: 383
# tram: 65
# car: 3953
# misc: 135
# pedestrian: 727
# truck: 142
# person_sitting: 29
# dontcare: 1602
#
# 2020-06-28 12:01:17,199 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 0
# 2020-06-28 12:01:17,821 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 1
# 2020-06-28 12:01:18,442 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 2
# 2020-06-28 12:01:19,057 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 3
# 2020-06-28 12:01:19,685 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 4
# 2020-06-28 12:01:20,308 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 5
# 2020-06-28 12:01:20,960 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 6
# 2020-06-28 12:01:21,597 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 7
# 2020-06-28 12:01:22,222 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 8
# 2020-06-28 12:01:22,846 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 9
# 2020-06-28 12:01:23,479 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# cyclist: 1375
# van: 2531
# tram: 446
# misc: 838
# person_sitting: 193
# pedestrian: 3760
# truck: 952
# car: 24789
# dontcare: 9693
#
# 2020-06-28 12:01:23,479 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Cumulative object statistics
# 2020-06-28 12:01:23,479 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# cyclist: 1627
# van: 2914
# tram: 511
# car: 28742
# misc: 973
# pedestrian: 4487
# truck: 1094
# person_sitting: 222
# dontcare: 11295
#
# 2020-06-28 12:01:23,479 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Class map.
# Label in GT: Label in tfrecords file
# Cyclist: cyclist
# Van: van
# Tram: tram
# Car: car
# Misc: misc
# Pedestrian: pedestrian
# Truck: truck
# Person_sitting: person_sitting
# DontCare: dontcare
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2020-06-28 12:01:23,479 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Tfrecords generation complete.

# %%
# !ls -rlt $DATA_DOWNLOAD_DIR/tfrecords/kitti_trainval
# Out:
# total 7136
# -rw-r--r-- 1 root root 104563 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 102704 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 102153 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root  97636 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root  98167 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 103687 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 101947 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root 100557 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root  99253 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 110021 Jun 28 12:01 kitti_trainval-fold-000-of-002-shard-00009-of-00010
# -rw-r--r-- 1 root root 626626 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 629770 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 619792 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root 630271 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root 632187 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 612981 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 624953 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root 623884 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root 620635 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 631471 Jun 28 12:01 kitti_trainval-fold-001-of-002-shard-00009-of-00010

# %% [markdown]
# ### 1.2 Download pre-trained model <a class="anchor" id="head-1-2"></a>

# %% [markdown]
# We will use NGC CLI to get the pre-trained models. For more details, go to [ngc.nvidia.com](ngc.nvidia.com) and click the SETUP on the navigation bar.

# %%
# !ngc registry model list nvidia/tlt_pretrained_object_detection:*
# Out:
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | Versi | Accur | Epoch | Batch | GPU   | Memor | File  | Statu | Creat |
# | on    | acy   | s     | Size  | Model | y Foo | Size  | s     | ed    |
# |       |       |       |       |       | tprin |       |       | Date  |
# |       |       |       |       |       | t     |       |       |       |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | resne | 74.38 | 80    | 1     | V100  | 38.3  | 38.31 | UPLOA | Apr   |
# | t10   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 76.74 | 80    | 1     | V100  | 89.0  | 88.96 | UPLOA | Apr   |
# | t18   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 77.04 | 80    | 1     | V100  | 170.7 | 170.6 | UPLOA | Apr   |
# | t34   |       |       |       |       |       | 5 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 77.91 | 80    | 1     | V100  | 294.2 | 294.2 | UPLOA | Apr   |
# | t50   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 69.87 | 80    | 1     | V100  | 576.3 | 576.3 | UPLOA | Apr   |
# | t101  |       |       |       |       |       | 3 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | vgg16 | 77.17 | 80    | 1     | V100  | 113.2 | 113.1 | UPLOA | Apr   |
# |       |       |       |       |       |       | 6 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | vgg19 | 77.56 | 80    | 1     | V100  | 153.7 | 153.7 | UPLOA | Apr   |
# |       |       |       |       |       |       | 2 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | darkn | 76.44 | 80    | 1     | V100  | 311.7 | 311.6 | UPLOA | Apr   |
# | et53  |       |       |       |       |       | 8 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | darkn | 77.52 | 80    | 1     | V100  | 152.8 | 152.8 | UPLOA | Apr   |
# | et19  |       |       |       |       |       | 2 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | mobil | 72.75 | 80    | 1     | V100  | 5.0   | 5.01  | UPLOA | Apr   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 29,   |
# | v2    |       |       |       |       |       |       | PLETE | 2020  |
# | squee | 65.13 | 80    | 1     | V100  | 6.5   | 6.46  | UPLOA | Apr   |
# | zenet |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | googl | 77.11 | 80    | 1     | V100  | 47.6  | 47.64 | UPLOA | Apr   |
# | enet  |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | mobil | 79.5  | 80    | 1     | V100  | 26.2  | 26.22 | UPLOA | Apr   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 29,   |
# | v1    |       |       |       |       |       |       | PLETE | 2020  |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/pretrained_resnet18/

# %%
# Pull pretrained model from NGC
# !ngc registry model download-version nvidia/tlt_pretrained_object_detection:resnet18 --dest $USER_EXPERIMENT_DIR/pretrained_resnet18
# Out:
# Downloaded 82.38 MB in 1m 1s, Download speed: 1.35 MB/s
# ----------------------------------------------------
# Transfer id: tlt_pretrained_object_detection_vresnet18 Download status: Completed.
# Downloaded local path: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/pretrained_resnet18/tlt_pretrained_object_detection_vresnet18
# Total files downloaded: 1
# Total downloaded size: 82.38 MB
# Started at: 2020-06-28 12:03:25.873262
# Completed at: 2020-06-28 12:04:26.957205
# Duration taken: 1m 1s
# ----------------------------------------------------

# %%
print("Check that model is downloaded into dir.")
# !ls -lh $USER_EXPERIMENT_DIR/pretrained_resnet18/tlt_pretrained_object_detection_vresnet18
# Out:
# Check that model is downloaded into dir.
# total 89M
# -rw------- 1 root root 89M Jun 28 12:04 resnet_18.hdf5

# %% [markdown]
# ## 2. Provide training specification <a class="anchor" id="head-2"></a>
# * Tfrecords for the train datasets
#     * In order to use the newly generated tfrecords, update the dataset_config parameter in the spec file at `$SPECS_DIR/ssd_train_resnet18_kitti.txt`
#     * Update the fold number to use for evaluation. In case of random data split, please use fold 0 only
#     * For sequence wise you may use any fold generated from the dataset convert tool
# * Pre-trained models
# * Augmentation parameters for on the fly data augmentation
# * Other training (hyper-)parameters such as batch size, number of epochs, learning rate etc.

# %%
# !cat $SPECS_DIR/ssd_train_resnet18_kitti.txt
# Out:
# random_seed: 42
# ssd_config {
#   aspect_ratios_global: "[1.0, 2.0, 0.5, 3.0, 1.0/3.0]"
#   scales: "[0.05, 0.1, 0.25, 0.4, 0.55, 0.7, 0.85]"
#   two_boxes_for_ar1: true
#   clip_boxes: false
#   loss_loc_weight: 0.8
#   focal_loss_alpha: 0.25
#   focal_loss_gamma: 2.0
#   variances: "[0.1, 0.1, 0.2, 0.2]"
#   arch: "resnet"
#   nlayers: 18
#   freeze_bn: false
# }
# training_config {
#   batch_size_per_gpu: 24
#   num_epochs: 80
#   learning_rate {
#   soft_start_annealing_schedule {
#     min_learning_rate: 5e-5
#     max_learning_rate: 2e-2
#     soft_start: 0.15
#     annealing: 0.5
#     }
#   }
#   regularizer {
#     type: L1
#     weight: 3e-06
#   }
# }
# eval_config {
#   validation_period_during_training: 10
#   average_precision_mode: SAMPLE
#   batch_size: 32
#   matching_iou_threshold: 0.5
# }
# nms_config {
#   confidence_threshold: 0.01
#   clustering_iou_threshold: 0.6
#   top_k: 200
# }
# augmentation_config {
#   preprocessing {
#     output_image_width: 1248
#     output_image_height: 384
#     output_image_channel: 3
#     crop_right: 1248
#     crop_bottom: 384
#     min_bbox_width: 1.0
#     min_bbox_height: 1.0
#   }
#   spatial_augmentation {
#     hflip_probability: 0.5
#     vflip_probability: 0.0
#     zoom_min: 0.7
#     zoom_max: 1.8
#     translate_max_x: 8.0
#     translate_max_y: 8.0
#   }
#   color_augmentation {
#     hue_rotation_max: 25.0
#     saturation_shift_max: 0.20000000298
#     contrast_scale_max: 0.10000000149
#     contrast_center: 0.5
#   }
# }
# dataset_config {
#   data_sources: {
#     tfrecords_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/tfrecords/kitti_trainval/kitti_trainval*"
#     image_directory_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training"
#   }
#   image_extension: "png"
#   target_class_mapping {
#       key: "car"
#       value: "car"
#   }
#   target_class_mapping {
#       key: "pedestrian"
#       value: "pedestrian"
#   }
#   target_class_mapping {
#       key: "cyclist"
#       value: "cyclist"
#   }
#   target_class_mapping {
#       key: "van"
#       value: "car"
#   }
#   target_class_mapping {
#       key: "person_sitting"
#       value: "pedestrian"
#   }
# validation_fold: 0
# }

# %% [markdown]
# ## 3. Run TLT training <a class="anchor" id="head-3"></a>
# * Provide the sample spec file and the output directory location for models
# * WARNING: training will take several hours or one day to complete

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_unpruned

# %%
print("To run with multigpu, please change --gpus based on the number of available GPUs in your machine.")
# !tlt-train ssd -e $SPECS_DIR/ssd_train_resnet18_kitti.txt \
               -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
               -k $KEY \
               -m $USER_EXPERIMENT_DIR/pretrained_resnet18/tlt_pretrained_object_detection_vresnet18/resnet_18.hdf5 \
               --gpus 1
# Out:
# To run with multigpu, please change --gpus based on the number of available GPUs in your machine.
# Using TensorFlow backend.
# 2020-06-28 12:21:50,953 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/specs/ssd_train_resnet18_kitti.txt
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-06-28 12:22:17,474 [INFO] iva.ssd.scripts.train: Loading pretrained weights. This may take a while...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (24, 3, 384, 1248)   0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (24, 64, 192, 624)   9408        Input[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (24, 64, 192, 624)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (24, 64, 192, 624)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (24, 64, 96, 312)    36864       activation_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (24, 64, 96, 312)    256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (24, 64, 96, 312)    0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (24, 64, 96, 312)    36864       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (24, 64, 96, 312)    4096        activation_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (24, 64, 96, 312)    256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (24, 64, 96, 312)    256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (24, 64, 96, 312)    0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (24, 64, 96, 312)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (24, 64, 96, 312)    36864       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_1 (BatchNormalizati (24, 64, 96, 312)    256         block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (24, 64, 96, 312)    0           block_1b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (24, 64, 96, 312)    36864       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (24, 64, 96, 312)    4096        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_2 (BatchNormalizati (24, 64, 96, 312)    256         block_1b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_shortcut (BatchNorm (24, 64, 96, 312)    256         block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (24, 64, 96, 312)    0           block_1b_bn_2[0][0]
#                                                                  block_1b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (24, 64, 96, 312)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (24, 128, 48, 156)   73728       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (24, 128, 48, 156)   512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (24, 128, 48, 156)   0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (24, 128, 48, 156)   147456      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (24, 128, 48, 156)   8192        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (24, 128, 48, 156)   512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (24, 128, 48, 156)   512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (24, 128, 48, 156)   0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (24, 128, 48, 156)   0           add_11[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (24, 128, 48, 156)   147456      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_1 (BatchNormalizati (24, 128, 48, 156)   512         block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (24, 128, 48, 156)   0           block_2b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (24, 128, 48, 156)   147456      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (24, 128, 48, 156)   16384       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_2 (BatchNormalizati (24, 128, 48, 156)   512         block_2b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_shortcut (BatchNorm (24, 128, 48, 156)   512         block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (24, 128, 48, 156)   0           block_2b_bn_2[0][0]
#                                                                  block_2b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (24, 128, 48, 156)   0           add_12[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (24, 256, 24, 78)    294912      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (24, 256, 24, 78)    1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (24, 256, 24, 78)    0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (24, 256, 24, 78)    589824      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (24, 256, 24, 78)    32768       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (24, 256, 24, 78)    1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (24, 256, 24, 78)    1024        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (24, 256, 24, 78)    0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (24, 256, 24, 78)    0           add_13[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (24, 256, 24, 78)    589824      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_1 (BatchNormalizati (24, 256, 24, 78)    1024        block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (24, 256, 24, 78)    0           block_3b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (24, 256, 24, 78)    589824      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (24, 256, 24, 78)    65536       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_2 (BatchNormalizati (24, 256, 24, 78)    1024        block_3b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_shortcut (BatchNorm (24, 256, 24, 78)    1024        block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (24, 256, 24, 78)    0           block_3b_bn_2[0][0]
#                                                                  block_3b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (24, 256, 24, 78)    0           add_14[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (24, 512, 24, 78)    1179648     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (24, 512, 24, 78)    2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (24, 512, 24, 78)    0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (24, 512, 24, 78)    2359296     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (24, 512, 24, 78)    131072      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (24, 512, 24, 78)    2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (24, 512, 24, 78)    2048        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (24, 512, 24, 78)    0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (24, 512, 24, 78)    0           add_15[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (24, 512, 24, 78)    2359296     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_1 (BatchNormalizati (24, 512, 24, 78)    2048        block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (24, 512, 24, 78)    0           block_4b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (24, 512, 24, 78)    2359296     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (24, 512, 24, 78)    262144      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_2 (BatchNormalizati (24, 512, 24, 78)    2048        block_4b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_shortcut (BatchNorm (24, 512, 24, 78)    2048        block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (24, 512, 24, 78)    0           block_4b_bn_2[0][0]
#                                                                  block_4b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (24, 512, 24, 78)    0           add_16[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_conv_0 (Conv (24, 256, 24, 78)    131328      block_4b_relu[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_relu_0 (ReLU (24, 256, 24, 78)    0           ssd_expand_block_0_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_conv_1 (Conv (24, 256, 24, 78)    589824      ssd_expand_block_0_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_bn_1 (BatchN (24, 256, 24, 78)    1024        ssd_expand_block_0_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_relu_1 (ReLU (24, 256, 24, 78)    0           ssd_expand_block_0_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_0 (Conv (24, 128, 24, 78)    32896       ssd_expand_block_0_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_0 (ReLU (24, 128, 24, 78)    0           ssd_expand_block_1_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_1 (Conv (24, 256, 12, 39)    294912      ssd_expand_block_1_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_bn_1 (BatchN (24, 256, 12, 39)    1024        ssd_expand_block_1_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_1 (ReLU (24, 256, 12, 39)    0           ssd_expand_block_1_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_0 (Conv (24, 64, 12, 39)     16448       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_0 (ReLU (24, 64, 12, 39)     0           ssd_expand_block_2_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_1 (Conv (24, 128, 6, 20)     73728       ssd_expand_block_2_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_bn_1 (BatchN (24, 128, 6, 20)     512         ssd_expand_block_2_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_1 (ReLU (24, 128, 6, 20)     0           ssd_expand_block_2_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_0 (Conv (24, 64, 6, 20)      8256        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_0 (ReLU (24, 64, 6, 20)      0           ssd_expand_block_3_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_1 (Conv (24, 128, 3, 10)     73728       ssd_expand_block_3_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_bn_1 (BatchN (24, 128, 3, 10)     512         ssd_expand_block_3_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_1 (ReLU (24, 128, 3, 10)     0           ssd_expand_block_3_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_0 (Conv (24, 64, 3, 10)      8256        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_0 (ReLU (24, 64, 3, 10)      0           ssd_expand_block_4_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_1 (Conv (24, 128, 2, 5)      73728       ssd_expand_block_4_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_bn_1 (BatchN (24, 128, 2, 5)      512         ssd_expand_block_4_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_1 (ReLU (24, 128, 2, 5)      0           ssd_expand_block_4_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_0 (Conv2D)             (24, 18, 48, 156)    20754       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# ssd_conf_1 (Conv2D)             (24, 18, 24, 78)     41490       ssd_expand_block_0_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_2 (Conv2D)             (24, 18, 12, 39)     41490       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_3 (Conv2D)             (24, 18, 6, 20)      20754       ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_4 (Conv2D)             (24, 18, 3, 10)      20754       ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_5 (Conv2D)             (24, 18, 2, 5)       20754       ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# permute_13 (Permute)            (24, 48, 156, 18)    0           ssd_conf_0[0][0]
# __________________________________________________________________________________________________
# permute_15 (Permute)            (24, 24, 78, 18)     0           ssd_conf_1[0][0]
# __________________________________________________________________________________________________
# permute_17 (Permute)            (24, 12, 39, 18)     0           ssd_conf_2[0][0]
# __________________________________________________________________________________________________
# permute_19 (Permute)            (24, 6, 20, 18)      0           ssd_conf_3[0][0]
# __________________________________________________________________________________________________
# permute_21 (Permute)            (24, 3, 10, 18)      0           ssd_conf_4[0][0]
# __________________________________________________________________________________________________
# permute_23 (Permute)            (24, 2, 5, 18)       0           ssd_conf_5[0][0]
# __________________________________________________________________________________________________
# ssd_loc_0 (Conv2D)              (24, 24, 48, 156)    27672       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# ssd_loc_1 (Conv2D)              (24, 24, 24, 78)     55320       ssd_expand_block_0_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_2 (Conv2D)              (24, 24, 12, 39)     55320       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_3 (Conv2D)              (24, 24, 6, 20)      27672       ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_4 (Conv2D)              (24, 24, 3, 10)      27672       ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_5 (Conv2D)              (24, 24, 2, 5)       27672       ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# conf_reshape_0 (Reshape)        (24, 44928, 1, 3)    0           permute_13[0][0]
# __________________________________________________________________________________________________
# conf_reshape_1 (Reshape)        (24, 11232, 1, 3)    0           permute_15[0][0]
# __________________________________________________________________________________________________
# conf_reshape_2 (Reshape)        (24, 2808, 1, 3)     0           permute_17[0][0]
# __________________________________________________________________________________________________
# conf_reshape_3 (Reshape)        (24, 720, 1, 3)      0           permute_19[0][0]
# __________________________________________________________________________________________________
# conf_reshape_4 (Reshape)        (24, 180, 1, 3)      0           permute_21[0][0]
# __________________________________________________________________________________________________
# conf_reshape_5 (Reshape)        (24, 60, 1, 3)       0           permute_23[0][0]
# __________________________________________________________________________________________________
# permute_14 (Permute)            (24, 48, 156, 24)    0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# permute_16 (Permute)            (24, 24, 78, 24)     0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# permute_18 (Permute)            (24, 12, 39, 24)     0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# permute_20 (Permute)            (24, 6, 20, 24)      0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# permute_22 (Permute)            (24, 3, 10, 24)      0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# permute_24 (Permute)            (24, 2, 5, 24)       0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_0 (AnchorBoxes)      (24, 7488, 6, 8)     0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_1 (AnchorBoxes)      (24, 1872, 6, 8)     0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_2 (AnchorBoxes)      (24, 468, 6, 8)      0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_3 (AnchorBoxes)      (24, 120, 6, 8)      0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_4 (AnchorBoxes)      (24, 30, 6, 8)       0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_5 (AnchorBoxes)      (24, 10, 6, 8)       0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (24, 59928, 1, 3)    0           conf_reshape_0[0][0]
#                                                                  conf_reshape_1[0][0]
#                                                                  conf_reshape_2[0][0]
#                                                                  conf_reshape_3[0][0]
#                                                                  conf_reshape_4[0][0]
#                                                                  conf_reshape_5[0][0]
# __________________________________________________________________________________________________
# loc_reshape_0 (Reshape)         (24, 44928, 1, 4)    0           permute_14[0][0]
# __________________________________________________________________________________________________
# loc_reshape_1 (Reshape)         (24, 11232, 1, 4)    0           permute_16[0][0]
# __________________________________________________________________________________________________
# loc_reshape_2 (Reshape)         (24, 2808, 1, 4)     0           permute_18[0][0]
# __________________________________________________________________________________________________
# loc_reshape_3 (Reshape)         (24, 720, 1, 4)      0           permute_20[0][0]
# __________________________________________________________________________________________________
# loc_reshape_4 (Reshape)         (24, 180, 1, 4)      0           permute_22[0][0]
# __________________________________________________________________________________________________
# loc_reshape_5 (Reshape)         (24, 60, 1, 4)       0           permute_24[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_0 (Reshape)      (24, 44928, 1, 8)    0           ssd_anchor_0[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_1 (Reshape)      (24, 11232, 1, 8)    0           ssd_anchor_1[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_2 (Reshape)      (24, 2808, 1, 8)     0           ssd_anchor_2[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_3 (Reshape)      (24, 720, 1, 8)      0           ssd_anchor_3[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_4 (Reshape)      (24, 180, 1, 8)      0           ssd_anchor_4[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_5 (Reshape)      (24, 60, 1, 8)       0           ssd_anchor_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf_sigmoid (Activation)  (24, 59928, 1, 3)    0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (24, 59928, 1, 4)    0           loc_reshape_0[0][0]
#                                                                  loc_reshape_1[0][0]
#                                                                  loc_reshape_2[0][0]
#                                                                  loc_reshape_3[0][0]
#                                                                  loc_reshape_4[0][0]
#                                                                  loc_reshape_5[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (24, 59928, 1, 8)    0           anchor_reshape_0[0][0]
#                                                                  anchor_reshape_1[0][0]
#                                                                  anchor_reshape_2[0][0]
#                                                                  anchor_reshape_3[0][0]
#                                                                  anchor_reshape_4[0][0]
#                                                                  anchor_reshape_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (24, 59928, 1, 15)   0           mbox_conf_sigmoid[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# ssd_predictions (Reshape)       (24, 59928, 15)      0           concatenate_2[0][0]
# ==================================================================================================
# Total params: 13,236,476
# Trainable params: 13,223,036
# Non-trainable params: 13,440
# __________________________________________________________________________________________________
# 2020-06-28 12:25:29,465 [INFO] iva.ssd.scripts.train: Number of images in the training dataset:	  6434
# 2020-06-28 12:25:29,465 [INFO] iva.ssd.scripts.train: Number of images in the validation dataset:	  1047
# Epoch 1/80
# 269/269 [==============================] - 294s 1s/step - loss: 24.4598
#
# Epoch 00001: saving model to /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/experiment_dir_unpruned/weights/ssd_resnet18_epoch_001.tlt
# Epoch 2/80
# 269/269 [==============================] - 229s 851ms/step - loss: 4.9549
#
# Epoch 00002: saving model to /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/experiment_dir_unpruned/weights/ssd_resnet18_epoch_002.tlt
# Epoch 3/80
# 269/269 [==============================] - 230s 853ms/step - loss: 4.2724
#
# Epoch 00003: saving model to /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/experiment_dir_unpruned/weights/ssd_resnet18_epoch_003.tlt
# Epoch 4/80
# 140/269 [==============>...............] - ETA: 1:50 - loss: 3.6223^C
# Traceback (most recent call last):
#   File "/usr/local/bin/tlt-train-g1", line 8, in <module>
#     sys.exit(main())
#   File "./common/magnet_train.py", line 37, in main
#   File "./ssd/scripts/train.py", line 245, in main
#   File "./ssd/scripts/train.py", line 182, in run_experiment
#   File "/usr/local/lib/python2.7/dist-packages/keras/engine/training.py", line 1039, in fit
#     validation_steps=validation_steps)
#   File "/usr/local/lib/python2.7/dist-packages/keras/engine/training_arrays.py", line 154, in fit_loop
#     outs = f(ins)
#   File "/usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %%
print("To resume from checkpoint, please uncomment and run this instead. Change last two arguments accordingly.")
# !tlt-train ssd -e $SPECS_DIR/ssd_train_resnet18_kitti.txt \
               -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
               -k $KEY \
               -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_resnet18_epoch_003.tlt \
               --gpus 1 \
               --initial_epoch 4
# Out:
# To resume from checkpoint, please uncomment and run this instead. Change last two arguments accordingly.
# Using TensorFlow backend.
# 2020-06-28 12:42:23,114 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/specs/ssd_train_resnet18_kitti.txt
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-06-28 12:42:49,203 [INFO] iva.ssd.scripts.train: Loading pretrained weights. This may take a while...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (24, 3, 384, 1248)   0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (24, 64, 192, 624)   9408        Input[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (24, 64, 192, 624)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (24, 64, 192, 624)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (24, 64, 96, 312)    36864       activation_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (24, 64, 96, 312)    256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (24, 64, 96, 312)    0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (24, 64, 96, 312)    36864       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (24, 64, 96, 312)    4096        activation_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (24, 64, 96, 312)    256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (24, 64, 96, 312)    256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (24, 64, 96, 312)    0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (24, 64, 96, 312)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (24, 64, 96, 312)    36864       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_1 (BatchNormalizati (24, 64, 96, 312)    256         block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (24, 64, 96, 312)    0           block_1b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (24, 64, 96, 312)    36864       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (24, 64, 96, 312)    4096        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_2 (BatchNormalizati (24, 64, 96, 312)    256         block_1b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_shortcut (BatchNorm (24, 64, 96, 312)    256         block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (24, 64, 96, 312)    0           block_1b_bn_2[0][0]
#                                                                  block_1b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (24, 64, 96, 312)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (24, 128, 48, 156)   73728       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (24, 128, 48, 156)   512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (24, 128, 48, 156)   0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (24, 128, 48, 156)   147456      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (24, 128, 48, 156)   8192        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (24, 128, 48, 156)   512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (24, 128, 48, 156)   512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (24, 128, 48, 156)   0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (24, 128, 48, 156)   0           add_11[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (24, 128, 48, 156)   147456      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_1 (BatchNormalizati (24, 128, 48, 156)   512         block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (24, 128, 48, 156)   0           block_2b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (24, 128, 48, 156)   147456      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (24, 128, 48, 156)   16384       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_2 (BatchNormalizati (24, 128, 48, 156)   512         block_2b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_shortcut (BatchNorm (24, 128, 48, 156)   512         block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (24, 128, 48, 156)   0           block_2b_bn_2[0][0]
#                                                                  block_2b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (24, 128, 48, 156)   0           add_12[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (24, 256, 24, 78)    294912      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (24, 256, 24, 78)    1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (24, 256, 24, 78)    0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (24, 256, 24, 78)    589824      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (24, 256, 24, 78)    32768       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (24, 256, 24, 78)    1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (24, 256, 24, 78)    1024        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (24, 256, 24, 78)    0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (24, 256, 24, 78)    0           add_13[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (24, 256, 24, 78)    589824      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_1 (BatchNormalizati (24, 256, 24, 78)    1024        block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (24, 256, 24, 78)    0           block_3b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (24, 256, 24, 78)    589824      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (24, 256, 24, 78)    65536       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_2 (BatchNormalizati (24, 256, 24, 78)    1024        block_3b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_shortcut (BatchNorm (24, 256, 24, 78)    1024        block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (24, 256, 24, 78)    0           block_3b_bn_2[0][0]
#                                                                  block_3b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (24, 256, 24, 78)    0           add_14[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (24, 512, 24, 78)    1179648     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (24, 512, 24, 78)    2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (24, 512, 24, 78)    0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (24, 512, 24, 78)    2359296     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (24, 512, 24, 78)    131072      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (24, 512, 24, 78)    2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (24, 512, 24, 78)    2048        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (24, 512, 24, 78)    0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (24, 512, 24, 78)    0           add_15[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (24, 512, 24, 78)    2359296     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_1 (BatchNormalizati (24, 512, 24, 78)    2048        block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (24, 512, 24, 78)    0           block_4b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (24, 512, 24, 78)    2359296     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (24, 512, 24, 78)    262144      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_2 (BatchNormalizati (24, 512, 24, 78)    2048        block_4b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_shortcut (BatchNorm (24, 512, 24, 78)    2048        block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (24, 512, 24, 78)    0           block_4b_bn_2[0][0]
#                                                                  block_4b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (24, 512, 24, 78)    0           add_16[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_conv_0 (Conv (24, 256, 24, 78)    131328      block_4b_relu[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_relu_0 (ReLU (24, 256, 24, 78)    0           ssd_expand_block_0_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_conv_1 (Conv (24, 256, 24, 78)    589824      ssd_expand_block_0_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_bn_1 (BatchN (24, 256, 24, 78)    1024        ssd_expand_block_0_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_0_relu_1 (ReLU (24, 256, 24, 78)    0           ssd_expand_block_0_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_0 (Conv (24, 128, 24, 78)    32896       ssd_expand_block_0_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_0 (ReLU (24, 128, 24, 78)    0           ssd_expand_block_1_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_1 (Conv (24, 256, 12, 39)    294912      ssd_expand_block_1_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_bn_1 (BatchN (24, 256, 12, 39)    1024        ssd_expand_block_1_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_1 (ReLU (24, 256, 12, 39)    0           ssd_expand_block_1_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_0 (Conv (24, 64, 12, 39)     16448       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_0 (ReLU (24, 64, 12, 39)     0           ssd_expand_block_2_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_1 (Conv (24, 128, 6, 20)     73728       ssd_expand_block_2_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_bn_1 (BatchN (24, 128, 6, 20)     512         ssd_expand_block_2_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_1 (ReLU (24, 128, 6, 20)     0           ssd_expand_block_2_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_0 (Conv (24, 64, 6, 20)      8256        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_0 (ReLU (24, 64, 6, 20)      0           ssd_expand_block_3_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_1 (Conv (24, 128, 3, 10)     73728       ssd_expand_block_3_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_bn_1 (BatchN (24, 128, 3, 10)     512         ssd_expand_block_3_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_1 (ReLU (24, 128, 3, 10)     0           ssd_expand_block_3_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_0 (Conv (24, 64, 3, 10)      8256        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_0 (ReLU (24, 64, 3, 10)      0           ssd_expand_block_4_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_1 (Conv (24, 128, 2, 5)      73728       ssd_expand_block_4_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_bn_1 (BatchN (24, 128, 2, 5)      512         ssd_expand_block_4_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_1 (ReLU (24, 128, 2, 5)      0           ssd_expand_block_4_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_0 (Conv2D)             (24, 18, 48, 156)    20754       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# ssd_conf_1 (Conv2D)             (24, 18, 24, 78)     41490       ssd_expand_block_0_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_2 (Conv2D)             (24, 18, 12, 39)     41490       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_3 (Conv2D)             (24, 18, 6, 20)      20754       ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_4 (Conv2D)             (24, 18, 3, 10)      20754       ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_5 (Conv2D)             (24, 18, 2, 5)       20754       ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# permute_13 (Permute)            (24, 48, 156, 18)    0           ssd_conf_0[0][0]
# __________________________________________________________________________________________________
# permute_15 (Permute)            (24, 24, 78, 18)     0           ssd_conf_1[0][0]
# __________________________________________________________________________________________________
# permute_17 (Permute)            (24, 12, 39, 18)     0           ssd_conf_2[0][0]
# __________________________________________________________________________________________________
# permute_19 (Permute)            (24, 6, 20, 18)      0           ssd_conf_3[0][0]
# __________________________________________________________________________________________________
# permute_21 (Permute)            (24, 3, 10, 18)      0           ssd_conf_4[0][0]
# __________________________________________________________________________________________________
# permute_23 (Permute)            (24, 2, 5, 18)       0           ssd_conf_5[0][0]
# __________________________________________________________________________________________________
# ssd_loc_0 (Conv2D)              (24, 24, 48, 156)    27672       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# ssd_loc_1 (Conv2D)              (24, 24, 24, 78)     55320       ssd_expand_block_0_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_2 (Conv2D)              (24, 24, 12, 39)     55320       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_3 (Conv2D)              (24, 24, 6, 20)      27672       ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_4 (Conv2D)              (24, 24, 3, 10)      27672       ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_5 (Conv2D)              (24, 24, 2, 5)       27672       ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# conf_reshape_0 (Reshape)        (24, 44928, 1, 3)    0           permute_13[0][0]
# __________________________________________________________________________________________________
# conf_reshape_1 (Reshape)        (24, 11232, 1, 3)    0           permute_15[0][0]
# __________________________________________________________________________________________________
# conf_reshape_2 (Reshape)        (24, 2808, 1, 3)     0           permute_17[0][0]
# __________________________________________________________________________________________________
# conf_reshape_3 (Reshape)        (24, 720, 1, 3)      0           permute_19[0][0]
# __________________________________________________________________________________________________
# conf_reshape_4 (Reshape)        (24, 180, 1, 3)      0           permute_21[0][0]
# __________________________________________________________________________________________________
# conf_reshape_5 (Reshape)        (24, 60, 1, 3)       0           permute_23[0][0]
# __________________________________________________________________________________________________
# permute_14 (Permute)            (24, 48, 156, 24)    0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# permute_16 (Permute)            (24, 24, 78, 24)     0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# permute_18 (Permute)            (24, 12, 39, 24)     0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# permute_20 (Permute)            (24, 6, 20, 24)      0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# permute_22 (Permute)            (24, 3, 10, 24)      0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# permute_24 (Permute)            (24, 2, 5, 24)       0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_0 (AnchorBoxes)      (24, 7488, 6, 8)     0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_1 (AnchorBoxes)      (24, 1872, 6, 8)     0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_2 (AnchorBoxes)      (24, 468, 6, 8)      0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_3 (AnchorBoxes)      (24, 120, 6, 8)      0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_4 (AnchorBoxes)      (24, 30, 6, 8)       0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_5 (AnchorBoxes)      (24, 10, 6, 8)       0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (24, 59928, 1, 3)    0           conf_reshape_0[0][0]
#                                                                  conf_reshape_1[0][0]
#                                                                  conf_reshape_2[0][0]
#                                                                  conf_reshape_3[0][0]
#                                                                  conf_reshape_4[0][0]
#                                                                  conf_reshape_5[0][0]
# __________________________________________________________________________________________________
# loc_reshape_0 (Reshape)         (24, 44928, 1, 4)    0           permute_14[0][0]
# __________________________________________________________________________________________________
# loc_reshape_1 (Reshape)         (24, 11232, 1, 4)    0           permute_16[0][0]
# __________________________________________________________________________________________________
# loc_reshape_2 (Reshape)         (24, 2808, 1, 4)     0           permute_18[0][0]
# __________________________________________________________________________________________________
# loc_reshape_3 (Reshape)         (24, 720, 1, 4)      0           permute_20[0][0]
# __________________________________________________________________________________________________
# loc_reshape_4 (Reshape)         (24, 180, 1, 4)      0           permute_22[0][0]
# __________________________________________________________________________________________________
# loc_reshape_5 (Reshape)         (24, 60, 1, 4)       0           permute_24[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_0 (Reshape)      (24, 44928, 1, 8)    0           ssd_anchor_0[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_1 (Reshape)      (24, 11232, 1, 8)    0           ssd_anchor_1[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_2 (Reshape)      (24, 2808, 1, 8)     0           ssd_anchor_2[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_3 (Reshape)      (24, 720, 1, 8)      0           ssd_anchor_3[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_4 (Reshape)      (24, 180, 1, 8)      0           ssd_anchor_4[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_5 (Reshape)      (24, 60, 1, 8)       0           ssd_anchor_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf_sigmoid (Activation)  (24, 59928, 1, 3)    0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (24, 59928, 1, 4)    0           loc_reshape_0[0][0]
#                                                                  loc_reshape_1[0][0]
#                                                                  loc_reshape_2[0][0]
#                                                                  loc_reshape_3[0][0]
#                                                                  loc_reshape_4[0][0]
#                                                                  loc_reshape_5[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (24, 59928, 1, 8)    0           anchor_reshape_0[0][0]
#                                                                  anchor_reshape_1[0][0]
#                                                                  anchor_reshape_2[0][0]
#                                                                  anchor_reshape_3[0][0]
#                                                                  anchor_reshape_4[0][0]
#                                                                  anchor_reshape_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (24, 59928, 1, 15)   0           mbox_conf_sigmoid[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# ssd_predictions (Reshape)       (24, 59928, 15)      0           concatenate_2[0][0]
# ==================================================================================================
# Total params: 13,236,476
# Trainable params: 13,223,036
# Non-trainable params: 13,440
# __________________________________________________________________________________________________
# 2020-06-28 12:47:15,156 [INFO] iva.ssd.scripts.train: Number of images in the training dataset:	  6434
# 2020-06-28 12:47:15,156 [INFO] iva.ssd.scripts.train: Number of images in the validation dataset:	  1047
# Epoch 4/80
# 269/269 [==============================] - 246s 913ms/step - loss: 3.5297
#
# Epoch 00004: saving model to /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/experiment_dir_unpruned/weights/ssd_resnet18_epoch_004.tlt
# Epoch 5/80
#  53/269 [====>.........................] - ETA: 3:03 - loss: 3.1524^C

# %%
print('Model for each epoch:')
print('---------------------')
# !ls -ltrh $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights

# %%
# Now check the evaluation stats in the csv file and pick the model with highest eval accuracy.
# Note csv epoch number is 1 less than model file epoch. For example, epoch 79 in csv corresponds to _080.tlt
# !cat $USER_EXPERIMENT_DIR/experiment_dir_unpruned/ssd_training_log_resnet18.csv
# %set_env EPOCH=080

# %% [markdown]
# ## 4. Evaluate trained models <a class="anchor" id="head-4"></a>

# %%
# !tlt-evaluate ssd -e $SPECS_DIR/ssd_train_resnet18_kitti.txt \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_resnet18_epoch_$EPOCH.tlt \
                  -k $KEY

# %% [markdown]
# ## 5. Prune trained models <a class="anchor" id="head-5"></a>
# * Specify pre-trained model
# * Equalization criterion (`Only for resnets as they have element wise operations or MobileNets.`)
# * Threshold for pruning.
# * A key to save and load the model
# * Output directory to store the model
#
# Usually, you just need to adjust `-pth` (threshold) for accuracy and model size trade off. Higher `pth` gives you smaller model (and thus higher inference speed) but worse accuracy. The threshold value depends on the dataset and the model. `0.5` in the block below is just a start point. If the retrain accuracy is good, you can increase this value to get smaller models. Otherwise, lower this value to get better accuracy.

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_pruned

# %%
# !tlt-prune -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_resnet18_epoch_$EPOCH.tlt \
           -o $USER_EXPERIMENT_DIR/experiment_dir_pruned/ssd_resnet18_pruned.tlt \
           -eq intersection \
           -pth 0.5 \
           -k $KEY

# %%
# !ls -rlt $USER_EXPERIMENT_DIR/experiment_dir_pruned/

# %% [markdown]
# ## 6. Retrain pruned models <a class="anchor" id="head-6"></a>
# * Model needs to be re-trained to bring back accuracy after pruning
# * Specify re-training specification
# * WARNING: training will take several hours or one day to complete

# %%
# Printing the retrain spec file. 
# Here we have updated the spec file to include the newly pruned model as a pretrained weights.
# !cat $SPECS_DIR/ssd_retrain_resnet18_kitti.txt

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_retrain

# %%
# Retraining using the pruned model as pretrained weights 
# !tlt-train ssd --gpus 1 \
               -e $SPECS_DIR/ssd_retrain_resnet18_kitti.txt \
               -r $USER_EXPERIMENT_DIR/experiment_dir_retrain \
               -m $USER_EXPERIMENT_DIR/experiment_dir_pruned/ssd_resnet18_pruned.tlt \
               -k $KEY

# %%
# Listing the newly retrained model.
# !ls -rlt $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights

# %%
# Now check the evaluation stats in the csv file and pick the model with highest eval accuracy.
# Note csv epoch number is 1 less than model file epoch. For example, epoch 79 in csv corresponds to _080.tlt
# !cat $USER_EXPERIMENT_DIR/experiment_dir_retrain/ssd_training_log_resnet18.csv
# %set_env EPOCH=100

# %% [markdown]
# ## 7. Evaluate retrained model <a class="anchor" id="head-7"></a>

# %%
# !tlt-evaluate ssd -e $SPECS_DIR/ssd_retrain_resnet18_kitti.txt \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_resnet18_epoch_$EPOCH.tlt \
                  -k $KEY

# %% [markdown]
# ## 8. Visualize inferences <a class="anchor" id="head-8"></a>
# In this section, we run the tlt-infer tool to generate inferences on the trained models and visualize the results.

# %%
# Running inference for detection on n images
# !tlt-infer ssd -i $DATA_DOWNLOAD_DIR/testing/image_2 \
               -o $USER_EXPERIMENT_DIR/ssd_infer_images \
               -e $SPECS_DIR/ssd_retrain_resnet18_kitti.txt \
               -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_resnet18_epoch_$EPOCH.tlt \
               -l $USER_EXPERIMENT_DIR/ssd_infer_labels \
               -k $KEY

# %% [markdown]
# The `tlt-infer` tool produces two outputs.
# 1. Overlain images in `$USER_EXPERIMENT_DIR/ssd_infer_images`
# 2. Frame by frame bbox labels in kitti format located in `$USER_EXPERIMENT_DIR/ssd_infer_labels`

# %%
# Simple grid visualizer
import matplotlib.pyplot as plt
import os
from math import ceil
valid_image_ext = ['.jpg', '.png', '.jpeg', '.ppm']

def visualize_images(image_dir, num_cols=4, num_images=10):
    output_path = os.path.join(os.environ['USER_EXPERIMENT_DIR'], image_dir)
    num_rows = int(ceil(float(num_images) / float(num_cols)))
    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
    f.tight_layout()
    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
         if os.path.splitext(image)[1].lower() in valid_image_ext]
    for idx, img_path in enumerate(a[:num_images]):
        col_id = idx % num_cols
        row_id = idx / num_cols
        img = plt.imread(img_path)
        axarr[row_id, col_id].imshow(img)

# %%
# Visualizing the sample images.
OUTPUT_PATH = 'ssd_infer_images' # relative path from $USER_EXPERIMENT_DIR.
COLS = 3 # number of columns in the visualizer grid.
IMAGES = 9 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 9. Deploy! <a class="anchor" id="head-9"></a>

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/export
# Export in FP32 mode. Change --data_type to fp16 for FP16 mode
# !tlt-export ssd -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_resnet18_epoch_$EPOCH.tlt \
                -k $KEY \
                -o $USER_EXPERIMENT_DIR/export/ssd_resnet18_epoch_$EPOCH.etlt \
                -e $SPECS_DIR/ssd_retrain_resnet18_kitti.txt \
                --batch_size 1 \
                --data_type fp32

# Uncomment to export in INT8 mode (generate calibration cache file). \
# !tlt-export ssd -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_resnet18_epoch_$EPOCH.tlt  \
#                 -o $USER_EXPERIMENT_DIR/export/ssd_resnet18_epoch_$EPOCH.etlt \
#                 -e $SPECS_DIR/ssd_retrain_resnet18_kitti.txt \
#                 -k $KEY \
#                 --cal_image_dir  $USER_EXPERIMENT_DIR/data/testing/image_2 \
#                 --data_type int8 \
#                 --batch_size 1 \
#                 --batches 10 \
#                 --cal_cache_file $USER_EXPERIMENT_DIR/export/cal.bin  \
#                 --cal_data_file $USER_EXPERIMENT_DIR/export/cal.tensorfile

# %% [markdown]
# `Note:` In this example, for ease of execution we restrict the number of calibrating batches to 10. TLT recommends the use of at least 10% of the training dataset for int8 calibration.

# %%
print('Exported model:')
print('------------')
# !ls -lh $USER_EXPERIMENT_DIR/export

# %% [markdown]
# Verify engine generation using the `tlt-converter` utility included with the docker.
#
# The `tlt-converter` produces optimized tensorrt engines for the platform that it resides on. Therefore, to get maximum performance, please instantiate this docker and execute the `tlt-converter` command, with the exported `.etlt` file and calibration cache (for int8 mode) on your target device. The converter utility included in this docker only works for x86 devices, with discrete NVIDIA GPU's.
#
# For the jetson devices, please download the converter for jetson from the dev zone link [here](https://developer.nvidia.com/tlt-converter).
#
# If you choose to integrate your model into deepstream directly, you may do so by simply copying the exported `.etlt` file along with the calibration cache to the target device and updating the spec file that configures the `gst-nvinfer` element to point to this newly exported model. Usually this file is called `config_infer_primary.txt` for detection models and `config_infer_secondary_*.txt` for classification models.

# %%
# Convert to TensorRT engine (FP16)
# !tlt-converter -k $KEY \
               -d 3,384,1248 \
               -o NMS \
               -e $USER_EXPERIMENT_DIR/export/trt.engine \
               -m 1 \
               -t fp16 \
               -i nchw \
               $USER_EXPERIMENT_DIR/export/ssd_resnet18_epoch_$EPOCH.etlt

# Uncomment to convert to TensorRT engine (INT8).
# !tlt-converter -k $KEY  \
#                -d 3,384,1248 \
#                -o NMS \
#                -c $USER_EXPERIMENT_DIR/export/cal.bin \
#                -e $USER_EXPERIMENT_DIR/export/trt.engine \
#                -b 8 \
#                -m 1 \
#                -t int8 \
#                -i nchw \
#                $USER_EXPERIMENT_DIR/export/ssd_resnet18_epoch_$EPOCH.etlt

# %%
print('Exported engine:')
print('------------')
# !ls -lh $USER_EXPERIMENT_DIR/export/trt.engine

# %% [markdown]
# ## 10. Verify the deployed model <a class="anchor" id="head-10"></a>
# Verify the converted engine by visualizing TensorRT inferences.

# %%
# Infer using TensorRT engine
# Note that tlt-infer currently only supports TensorRT engines with batch of 1. 
# Please make sure to use `-m 1` in tlt-converter and `--batch_size 1` in tlt-export

# When integrating with DS, please feel free to use any batch size that the GPU may be able to fit. 
# The engine batch size once created, cannot be alterred. So if you wish to run with a different batch-size,
# please re-run tlt-convert with the new batch-size for DS.

# !tlt-infer ssd --trt -p $USER_EXPERIMENT_DIR/export/trt.engine \
                     -e $SPECS_DIR/ssd_retrain_resnet18_kitti.txt \
                     -i $DATA_DOWNLOAD_DIR/testing/image_2 \
                     -o $USER_EXPERIMENT_DIR/ssd_infer_images \
                     -t 0.4
