# %% [markdown]
# # TLT SSD example usecase
#
# 本教程将详细讲述如何利用NVIDIA Transfer Learning toolkit从头开始训练一个口罩检测的模型，并将模型转换成可以直接部署在NVIDIA GPU（Tesla & Jetson）上的格式.
#
# 0. [设置环境变量](#head-0)
# 1. [准备数据集和预训练模型](#head-1) <br>
#     1.1 [将数据集转换成KITTI格式并生成TFrecord文件](#head-1-1) <br>
#     1.2 [下载预训练模型](#head-1-2) <br>
# 2. [设置训练参数](#head-2)
# 3. [利用NVIDIA Transfer Learning Toolkit训练模型](#head-3)
# 4. [评估模型](#head-4)
# 5. [模型剪枝](#head-5)
# 6. [重新训练剪枝后的模型](#head-6)
# 7. [评估重新训练的模型](#head-7)
# 8. [可视化推理过程](#head-8)
# 9. [模型的导出和部署](#head-9)
# 10. [确认导出模型](#head-10)

# %% [markdown]
# ## 0. 设置环境变量 <a class="anchor" id="head-0"></a>

# %%
# 设置环境变量，这里请注意KEY是需要您从NGC官网申请的，您可以从以下网址得到您自己的KEY：
#https://ngc.nvidia.com/catalog
#USER_EXPERIMENT_DIR是我们实验的目录
#DATA_DOWNLOAD_DIR是用来保存我们的数据样本和预训练模型
#SPECS_DIR是用来保存我们训练设置的超参
#以下设置仅代表作者本人的设置目录，需要用户根据自己的实际情况设置更新
print("Please replace the variable with your key.")
# %set_env KEY=OHB1YTZ0Z2RxYTBzdnE3YTNpcnVydmM4cXI6OGVkNDU4ZGQtNjViOC00NzYxLWFhMDUtMjgxMDQ2ZTVmNzAx
# %set_env USER_EXPERIMENT_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano
# %set_env DATA_DOWNLOAD_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data
# %set_env SPECS_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/specs
# !mkdir -p $USER_EXPERIMENT_DIR
# !mkdir -p $DATA_DOWNLOAD_DIR
# !mkdir -p $SPECS_DIR
# Out:
# Please replace the variable with your key.
# env: KEY=OHB1YTZ0Z2RxYTBzdnE3YTNpcnVydmM4cXI6OGVkNDU4ZGQtNjViOC00NzYxLWFhMDUtMjgxMDQ2ZTVmNzAx
# env: USER_EXPERIMENT_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano
# env: DATA_DOWNLOAD_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data
# env: SPECS_DIR=/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/specs

# %% [markdown]
# ## 1. 准备训练数据集和下载预训练模型 <a class="anchor" id="head-1"></a>

# %%
#验证KEY是否设置成功，这个KEY非常重要，用户训练出来的模型在导出和转换时都需要
# !echo $KEY
# Out:
# OHB1YTZ0Z2RxYTBzdnE3YTNpcnVydmM4cXI6OGVkNDU4ZGQtNjViOC00NzYxLWFhMDUtMjgxMDQ2ZTVmNzAx

# %% [markdown]
#  NVIDIA官方教程中使用的KITTI目标检测数据集，您可以通过以下网址下载：
#  http://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=2d.
#
#  图片下载网址： (http://www.cvlibs.net/download.php?file=data_object_image_2.zip)
#
#  标注下载网址： (http://www.cvlibs.net/download.php?file=data_object_label_2.zip)
#
#  下载好之后，把数据集放到$DATA_DOWNLOAD_DIR文件夹中.

# %%
# 查看上面下载的数据----这步当前实验可以不运行
# !mkdir -p $DATA_DOWNLOAD_DIR
# !if [ ! -f $DATA_DOWNLOAD_DIR/data_object_image_2.zip ]; then echo 'Image zip file not found, please download.'; else echo 'Found Image zip file.';fi
# !if [ ! -f $DATA_DOWNLOAD_DIR/data_object_label_2.zip ]; then echo 'Label zip file not found, please download.'; else echo 'Found Labels zip file.';fi
# Out:
# Found Image zip file.
# Found Labels zip file.

# %%
# 解压----这步当前实验可以不运行
# !unzip -u $DATA_DOWNLOAD_DIR/data_object_image_2.zip -d $DATA_DOWNLOAD_DIR
# !unzip -u $DATA_DOWNLOAD_DIR/data_object_label_2.zip -d $DATA_DOWNLOAD_DIR
# Out:
# Archive:  /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/data_object_image_2.zip
#    creating: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002480.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005952.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000709.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000814.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006192.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006017.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002731.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005295.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005347.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005326.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005713.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007000.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004353.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003969.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001973.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001440.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007083.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000166.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004479.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003732.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003998.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001768.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003576.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006565.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001665.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001604.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002037.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006729.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006666.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001928.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007175.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001303.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002893.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006514.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002445.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005183.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006688.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001083.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005950.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000649.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005488.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001456.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005091.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000946.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003063.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003944.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000228.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005904.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002274.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005069.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006011.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002942.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003887.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006863.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006324.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002627.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002437.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002894.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004121.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003942.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003876.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000671.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004735.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003837.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003218.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006476.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000913.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000921.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007144.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006205.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007121.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000549.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004275.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002795.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003670.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007140.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004100.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007188.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007235.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002612.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006289.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002406.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005755.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004368.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005192.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000163.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001229.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004036.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006216.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001394.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000894.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003293.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002474.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006360.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007271.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004064.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001038.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003072.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006133.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002007.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006845.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004852.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006323.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003222.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004169.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006738.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005628.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001842.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004363.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007115.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001598.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000147.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001024.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004356.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001504.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002261.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005283.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006850.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006615.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000967.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003628.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001879.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005981.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000929.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004089.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000466.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002493.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002941.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001475.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004939.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006358.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005104.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002860.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006759.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000791.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001465.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000162.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005484.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005231.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006317.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005590.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003402.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003440.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001526.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007439.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003542.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005340.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006607.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000247.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004592.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001929.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003709.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003556.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003442.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000412.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005984.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007156.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001678.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005978.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006532.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005553.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004515.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005211.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004158.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006331.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002689.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002311.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007357.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005229.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006544.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005944.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001020.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005582.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000965.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000313.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002161.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000969.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002599.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006832.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003783.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002750.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002087.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003324.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004967.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001766.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005847.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005201.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005237.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001657.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005427.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003299.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002163.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005869.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003650.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006310.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007288.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003185.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005656.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005907.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000689.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003796.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004860.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003594.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001527.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000943.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003140.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001450.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004294.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006190.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001340.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005109.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002241.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005531.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005442.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000284.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004080.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000795.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007278.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003787.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004934.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004554.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003097.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004975.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003426.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003681.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003313.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007070.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002031.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002128.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006908.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002428.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001580.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003455.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002525.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004413.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003408.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000221.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000535.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004300.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004682.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006956.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001900.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000861.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006712.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001833.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006415.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006404.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000959.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002206.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002147.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002700.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003564.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002518.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006109.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005111.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004653.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002012.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000734.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006507.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002726.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001339.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004212.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007037.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003928.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002506.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001529.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001953.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001071.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001353.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002370.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000952.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005131.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001869.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000842.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000520.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004659.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002072.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001767.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005527.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000124.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004165.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006746.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007021.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001365.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004278.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006655.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005164.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001898.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005608.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002073.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003991.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000203.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004728.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001266.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001044.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000578.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005169.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003677.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006093.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005365.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005140.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006604.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006095.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007466.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006423.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003358.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005547.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002532.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003970.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004282.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001176.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003031.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003799.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001758.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001674.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002652.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006942.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005279.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005188.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007416.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003210.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000272.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003752.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000192.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005783.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002160.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003879.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003654.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003040.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006990.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004050.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005519.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003706.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001037.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004639.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003617.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001005.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001231.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006945.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002725.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006100.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003826.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000740.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002402.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006029.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004177.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005802.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005150.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004807.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001940.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002737.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005636.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000707.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001839.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001194.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005649.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002338.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004210.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000306.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000928.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007265.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006285.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001208.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001806.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005909.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004636.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006714.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000016.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001956.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003802.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000937.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002452.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005016.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004598.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001762.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005077.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000729.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005750.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003167.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000551.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004801.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003444.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004331.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003470.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004151.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001178.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007219.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002318.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000701.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001622.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002507.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003531.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006502.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000077.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004954.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005256.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000103.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006380.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000828.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002786.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000606.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000188.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005507.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000151.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002415.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000743.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006275.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002130.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005021.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005764.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004582.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005982.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002531.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005299.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004657.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006234.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005481.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000212.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005003.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000493.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007358.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004271.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000902.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002443.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001204.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002329.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001783.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000878.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006431.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006157.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006241.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007246.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005724.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005337.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006526.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006504.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001388.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000410.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005101.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/007161.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000513.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004710.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002503.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004843.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001782.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005311.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003461.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003574.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000964.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000146.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000459.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006104.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005307.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004422.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001117.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000507.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002174.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001919.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004242.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005865.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002141.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005027.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/003067.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001874.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/006251.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004780.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000169.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/002590.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005880.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/001563.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/004460.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/005937.png
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/image_2/000492.png
# ...
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005130.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004292.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001157.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004590.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000949.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005460.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005681.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006498.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003450.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002917.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003416.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003110.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004479.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003641.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004574.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003894.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000915.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001883.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006140.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005843.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001394.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002465.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001594.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007432.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004802.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002857.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003499.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006385.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002035.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007448.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003571.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006407.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001281.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006241.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005800.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001612.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003903.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002404.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006251.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006406.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001544.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003251.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006844.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007447.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001585.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002885.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002342.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006862.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001125.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005619.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005003.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006145.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002762.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000931.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005798.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006798.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006811.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001899.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000568.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001329.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007458.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000849.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004117.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003545.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003711.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000602.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001254.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003070.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003211.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003445.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006530.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002672.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005759.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006692.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005022.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002803.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007315.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004939.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001839.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003329.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005126.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007134.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002640.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005978.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002548.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000472.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004831.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004688.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000504.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005558.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002629.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007154.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006763.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003852.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006750.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000889.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005075.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002346.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005027.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005320.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006186.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000731.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006136.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001915.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005965.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004288.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000830.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003720.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004373.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007385.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006528.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005567.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003068.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001396.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002127.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003740.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002928.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005309.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004123.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004618.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000295.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001089.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007121.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007043.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003204.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000566.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005153.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005255.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000639.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003104.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005909.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003362.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006327.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006531.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004583.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005928.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001282.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006347.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001629.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002889.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004964.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005101.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004359.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002288.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/003324.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006875.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005407.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/007414.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002625.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/000730.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/005747.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001455.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/006386.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002777.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/001730.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002740.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/002057.txt
#  extracting: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/label_2/004455.txt

# %%
# 确认
# !ls -l $DATA_DOWNLOAD_DIR/
# Out:
# total 12280824
# -rwxrwxrwx 1 1000 1000 12569945557 Jun 28 05:00 data_object_image_2.zip
# -rw-r--r-- 1 root root     5601213 May 11  2018 data_object_label_2.zip
# drwxr-xr-x 3 root root        4096 Jun 28 09:15 testing
# drwxr-xr-x 4 root root        4096 Jun 28 09:16 training

# %% [markdown]
# * 我们本次实验使用的是网上多个数据集混合的训练样本，VOC格式的.xml数据标注方式，需要用户自己讲标注文件转换成KITTI的格式
#
# * 在本次实验当前的目录下，‘data’文件夹下的‘images’保存的是处理好的训练图片，‘labels’文件夹保存的是训练样本的标注文件
#
# * "xmlfiles"文件夹保存的是转换前的标注文件
#
# * "xml2kitti"文件夹保存的是转换VOC的.xml文件到KITT格式的工具
#
# * changename.py是用来统一更改后缀名的工具
#
# * check.py是用来检查图片是否有损坏的工具（比如某个作者之前遇到的错误是某个图片以‘BM’开头，系统会报告格式错误）

# %% [markdown]
# ### 1.1 将准备好的训练数据从KITTI格式生成TFrecords格式 <a class="anchor" id="head-1-1"></a>
#
# * 更改在specs文件夹中的ssd_tfrecords_kitti_trainval.txt中的参数，指定训练样本的路径
# * 利用tlt-dataset-convert 生成TFrecords文件
# * TFRecords文件只需要生成一次既可
# * 注意这里的路径都是作者本人的环境路径，请用户自行更换成自己的环境路径

# %%
print("TFrecords conversion spec file for training")
# !cat $SPECS_DIR/ssd_tfrecords_kitti_trainval.txt
# Out:
# TFrecords conversion spec file for training
# kitti_config {
#   root_directory_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training"
#   image_dir_name: "images"
#   label_dir_name: "labels"
#   image_extension: ".png"
#   partition_mode: "random"
#   num_partitions: 2
#   val_split: 14
#   num_shards: 10
# }
# image_directory_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/images"

# %%
# 创建一个新的文件夹来存储tfrecords文件.
# !mkdir -p $USER_EXPERIMENT_DIR/tfrecords
#创建tfrecords文件 ‘-d’指的是设置文件，就是我们上一步更改的那个，‘-o’指的是输出
#目录。
# !tlt-dataset-convert -d $SPECS_DIR/ssd_tfrecords_kitti_trainval.txt \
                     -o $USER_EXPERIMENT_DIR/tfrecords/kitti_trainval/kitti_trainval
# Out:
# Using TensorFlow backend.
# 2020-06-28 11:01:57,450 - iva.detectnet_v2.dataio.build_converter - INFO - Instantiating a kitti converter
# 2020-06-28 11:01:57,451 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Creating output directory /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/tfrecords/kitti_trainval
# 2020-06-28 11:01:57,490 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Num images in
# Train: 6434	Val: 1047
# 2020-06-28 11:01:57,490 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2020-06-28 11:01:57,494 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 0
# /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/dataio/kitti_converter_lib.py:266: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 2020-06-28 11:01:59,131 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 1
# 2020-06-28 11:02:00,663 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 2
# 2020-06-28 11:02:02,137 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 3
# 2020-06-28 11:02:03,573 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 4
# 2020-06-28 11:02:05,019 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 5
# 2020-06-28 11:02:06,500 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 6
# 2020-06-28 11:02:07,972 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 7
# 2020-06-28 11:02:09,484 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 8
# 2020-06-28 11:02:10,997 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 9
# 2020-06-28 11:02:12,532 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# cyclist: 252
# van: 383
# tram: 65
# car: 3953
# misc: 135
# pedestrian: 727
# truck: 142
# person_sitting: 29
# dontcare: 1602
#
# 2020-06-28 11:02:12,532 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 0
# 2020-06-28 11:02:23,259 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 1
# 2020-06-28 11:02:32,319 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 2
# 2020-06-28 11:02:41,812 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 3
# 2020-06-28 11:02:53,397 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 4
# 2020-06-28 11:03:03,363 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 5
# 2020-06-28 11:03:12,755 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 6
# 2020-06-28 11:03:22,766 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 7
# 2020-06-28 11:03:32,241 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 8
# 2020-06-28 11:03:43,306 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 9
# 2020-06-28 11:03:53,064 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# cyclist: 1375
# van: 2531
# tram: 446
# misc: 838
# person_sitting: 193
# pedestrian: 3760
# truck: 952
# car: 24789
# dontcare: 9693
#
# 2020-06-28 11:03:53,064 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Cumulative object statistics
# 2020-06-28 11:03:53,064 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# cyclist: 1627
# van: 2914
# tram: 511
# car: 28742
# misc: 973
# pedestrian: 4487
# truck: 1094
# person_sitting: 222
# dontcare: 11295
#
# 2020-06-28 11:03:53,065 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Class map.
# Label in GT: Label in tfrecords file
# Cyclist: cyclist
# Van: van
# Tram: tram
# Car: car
# Misc: misc
# Pedestrian: pedestrian
# Truck: truck
# Person_sitting: person_sitting
# DontCare: dontcare
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2020-06-28 11:03:53,065 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Tfrecords generation complete.

# %%
#查看生成的文件
# !ls -rlt $USER_EXPERIMENT_DIR/tfrecords/kitti_trainval
# Out:
# total 7136
# -rw-r--r-- 1 root root 104459 Jun 28 11:01 kitti_trainval-fold-000-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 102600 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 102049 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root  97532 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root  98063 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 103583 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 101843 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root 100453 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root  99149 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 109910 Jun 28 11:02 kitti_trainval-fold-000-of-002-shard-00009-of-00010
# -rw-r--r-- 1 root root 625983 Jun 28 11:02 kitti_trainval-fold-001-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 629127 Jun 28 11:02 kitti_trainval-fold-001-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 619149 Jun 28 11:02 kitti_trainval-fold-001-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root 629628 Jun 28 11:02 kitti_trainval-fold-001-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root 631544 Jun 28 11:03 kitti_trainval-fold-001-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 612338 Jun 28 11:03 kitti_trainval-fold-001-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 624310 Jun 28 11:03 kitti_trainval-fold-001-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root 623241 Jun 28 11:03 kitti_trainval-fold-001-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root 619992 Jun 28 11:03 kitti_trainval-fold-001-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 630824 Jun 28 11:03 kitti_trainval-fold-001-of-002-shard-00009-of-00010

# %% [markdown]
# ### 1.2 下载预训练模型 <a class="anchor" id="head-1-2"></a>

# %% [markdown]
# 您可以通过一下命令下载模型，也可以通过手动的方式下载预训练模型：
# [ngc.nvidia.com](ngc.nvidia.com)

# %%
#查看当前目标检测可用的预训练模型
# !ngc registry model list nvidia/tlt_pretrained_object_detection:*
# Out:
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | Versi | Accur | Epoch | Batch | GPU   | Memor | File  | Statu | Creat |
# | on    | acy   | s     | Size  | Model | y Foo | Size  | s     | ed    |
# |       |       |       |       |       | tprin |       |       | Date  |
# |       |       |       |       |       | t     |       |       |       |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | resne | 74.38 | 80    | 1     | V100  | 38.3  | 38.31 | UPLOA | Apr   |
# | t10   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 76.74 | 80    | 1     | V100  | 89.0  | 88.96 | UPLOA | Apr   |
# | t18   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 77.04 | 80    | 1     | V100  | 170.7 | 170.6 | UPLOA | Apr   |
# | t34   |       |       |       |       |       | 5 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 77.91 | 80    | 1     | V100  | 294.2 | 294.2 | UPLOA | Apr   |
# | t50   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 69.87 | 80    | 1     | V100  | 576.3 | 576.3 | UPLOA | Apr   |
# | t101  |       |       |       |       |       | 3 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | vgg16 | 77.17 | 80    | 1     | V100  | 113.2 | 113.1 | UPLOA | Apr   |
# |       |       |       |       |       |       | 6 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | vgg19 | 77.56 | 80    | 1     | V100  | 153.7 | 153.7 | UPLOA | Apr   |
# |       |       |       |       |       |       | 2 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | darkn | 76.44 | 80    | 1     | V100  | 311.7 | 311.6 | UPLOA | Apr   |
# | et53  |       |       |       |       |       | 8 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | darkn | 77.52 | 80    | 1     | V100  | 152.8 | 152.8 | UPLOA | Apr   |
# | et19  |       |       |       |       |       | 2 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | mobil | 72.75 | 80    | 1     | V100  | 5.0   | 5.01  | UPLOA | Apr   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 29,   |
# | v2    |       |       |       |       |       |       | PLETE | 2020  |
# | squee | 65.13 | 80    | 1     | V100  | 6.5   | 6.46  | UPLOA | Apr   |
# | zenet |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | googl | 77.11 | 80    | 1     | V100  | 47.6  | 47.64 | UPLOA | Apr   |
# | enet  |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | mobil | 79.5  | 80    | 1     | V100  | 26.2  | 26.22 | UPLOA | Apr   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 29,   |
# | v1    |       |       |       |       |       |       | PLETE | 2020  |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+

# %%
#创建一个新的文件夹，存储下载好的预训练模型
# !mkdir -p $USER_EXPERIMENT_DIR/pretrained_mobilenet_v2/tlt_pretrained_object_detection_mobilenet_v2

# %%
# Pull pretrained model from NGC
# !ngc registry model download-version nvidia/tlt_pretrained_object_detection:mobilenet_v2 --dest $USER_EXPERIMENT_DIR/pretrained_mobilenet_v2/tlt_pretrained_object_detection_mobilenet_v2
# Out:
# Downloaded 4.3 MB in 14s, Download speed: 313.95 KB/s
# ----------------------------------------------------
# Transfer id: tlt_pretrained_object_detection_vmobilenet_v2 Download status: Completed.
# Downloaded local path: /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/pretrained_mobilenet_v2/tlt_pretrained_object_detection_mobilenet_v2/tlt_pretrained_object_detection_vmobilenet_v2
# Total files downloaded: 1
# Total downloaded size: 4.3 MB
# Started at: 2020-06-28 09:22:01.245271
# Completed at: 2020-06-28 09:22:15.266408
# Duration taken: 14s
# ----------------------------------------------------

# %%
print("查看下载好的预训练模型.")
# !ls -l $USER_EXPERIMENT_DIR/pretrained_mobilenet_v2/tlt_pretrained_object_detection_mobilenet_v2
# Out:
# 查看下载好的预训练模型.
# total 4
# drwx------ 2 root root 4096 Jun 28 09:22 tlt_pretrained_object_detection_vmobilenet_v2

# %% [markdown]
# ## 2. 设置训练的超参 <a class="anchor" id="head-2"></a>
# * 训练数据集
#     * 为了使用最新生成TFrecords文件，在 `$SPECS_DIR/ssd_train_resnet18_kitti.txt`设置文件路径
#     * Update the fold number to use for evaluation. In case of random data split, please use fold 0 only
#     * 更新测试样本数量，如果随机生成，可以设置成0
# * 预训练模型
# * 其他超参比如batch size，learning rate等等

# %%
# !cat $SPECS_DIR/ssd_train_mobilenet_v2_kitti.txt
# Out:
# random_seed: 42
# ssd_config {
#   aspect_ratios_global: "[1.0, 2.0, 0.5, 3.0, 1.0/3.0]"
#   scales: "[0.05, 0.1, 0.25, 0.4, 0.55, 0.7, 0.85]"
#   two_boxes_for_ar1: true
#   clip_boxes: false
#   loss_loc_weight: 0.8
#   focal_loss_alpha: 0.25
#   focal_loss_gamma: 2.0
#   variances: "[0.1, 0.1, 0.2, 0.2]"
#   arch: "mobilenet_v2"
#   freeze_bn: false
# }
# training_config {
#   batch_size_per_gpu: 64
#   num_epochs: 100
#   learning_rate {
#   soft_start_annealing_schedule {
#     min_learning_rate: 5e-7
#     max_learning_rate: 5e-3
#     soft_start: 0.1
#     annealing: 0.3
#     }
#   }
#   regularizer {
#     type: L2
#     weight: 0.00004
#   }
# }
# eval_config {
#   validation_period_during_training: 5
#   average_precision_mode: SAMPLE
#   batch_size: 32
#   matching_iou_threshold: 0.5
# }
# nms_config {
#   confidence_threshold: 0.01
#   clustering_iou_threshold: 0.6
#   top_k: 200
# }
# augmentation_config {
#   preprocessing {
#     output_image_width: 300
#     output_image_height: 300
#     output_image_channel: 3
#     crop_right: 300
#     crop_bottom: 300
#     min_bbox_width: 1.0
#     min_bbox_height: 1.0
#   }
#   spatial_augmentation {
#     hflip_probability: 0.5
#     vflip_probability: 0.0
#     zoom_min: 0.7
#     zoom_max: 1.8
#     translate_max_x: 8.0
#     translate_max_y: 8.0
#   }
#   color_augmentation {
#     hue_rotation_max: 25.0
#     saturation_shift_max: 0.20000000298
#     contrast_scale_max: 0.10000000149
#     contrast_center: 0.5
#   }
# }
# dataset_config {
#   data_sources: {
#     tfrecords_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/tfrecords/kitti_trainval/kitti_trainval*"
#     image_directory_path: "/workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/data/training/"
#   }
#   image_extension: "png"
#   target_class_mapping {
#       key: "face_mask"
#       value: "face_mask"
#   }
#   target_class_mapping {
#       key: "face"
#       value: "face"
#   }
# validation_fold: 0
# }

# %% [markdown]
# ## 3. 开始训练模型 <a class="anchor" id="head-3"></a>
# * 需要提供预训练模型、specs文件夹中的设置文件地址以及输出文件夹
# * 注意：训练课程会持续好几个小时或者一天

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_unpruned

# %%
print("如果想用多个GPU可以更改 ‘--gpus’的参数")
# !tlt-train ssd -e $SPECS_DIR/ssd_train_mobilenet_v2_kitti.txt \
               -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
               -k $KEY \
               -m /workspace-hekun/mydata/tlt-tensorrt-nano/pretrained_mobilenet_v2/tlt_pretrained_object_detection_mobilenet_v2/mobilenet_v2.hdf5 \
               --gpus 1
# Out:
# 如果想用多个GPU可以更改 ‘--gpus’的参数
# Using TensorFlow backend.
# 2020-06-28 11:22:16,382 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /workspace/tlt_docker_files/mydata/tlt-tensorrt-nano/specs/ssd_train_mobilenet_v2_kitti.txt
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-06-28 11:23:06,197 [INFO] iva.ssd.scripts.train: Loading pretrained weights. This may take a while...
# Traceback (most recent call last):
#   File "/usr/local/bin/tlt-train-g1", line 8, in <module>
#     sys.exit(main())
#   File "./common/magnet_train.py", line 37, in main
#   File "./ssd/scripts/train.py", line 245, in main
#   File "./ssd/scripts/train.py", line 123, in run_experiment
#   File "./ssd/utils/model_io.py", line 81, in load_model_as_pretrain
#   File "./ssd/utils/model_io.py", line 43, in load_model
#   File "/usr/local/lib/python2.7/dist-packages/keras/engine/saving.py", line 417, in load_model
#     f = h5dict(filepath, 'r')
#   File "/usr/local/lib/python2.7/dist-packages/keras/utils/io_utils.py", line 186, in __init__
#     self.data = h5py.File(path, mode=mode)
#   File "/usr/local/lib/python2.7/dist-packages/h5py/_hl/files.py", line 272, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#   File "/usr/local/lib/python2.7/dist-packages/h5py/_hl/files.py", line 92, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper (/tmp/pip-4rPeHA-build/h5py/_objects.c:2684)
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper (/tmp/pip-4rPeHA-build/h5py/_objects.c:2642)
#   File "h5py/h5f.pyx", line 76, in h5py.h5f.open (/tmp/pip-4rPeHA-build/h5py/h5f.c:1930)
# IOError: Unable to open file (Unable to open file: name = '/workspace-hekun/mydata/tlt-tensorrt-nano/pretrained_mobilenet_v2/tlt_pretrained_object_detection_mobilenet_v2/mobilenet_v2.hdf5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)

# %%
#查看训练出来的模型
# !ls /workspace-hekun/mydata/tlt-tensorrt-nano/experiment_dir_unpruned/weights/

# %%
print("To resume from checkpoint, please uncomment and run this instead. Change last two arguments accordingly.")
# !tlt-train ssd -e $SPECS_DIR/ssd_train_resnet18_kitti.txt \
#                -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
#                -k $KEY \
#                -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_resnet18_epoch_001.tlt \
#                --gpus 1 \
#                --initial_epoch 2

# %%
#查看训练出来的模型
print('Model for each epoch:')
print('---------------------')
# !ls -ltrh $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights

# %%
# 接下来通过评估的测试结果来选择一个训练效果最好的模型
# Note csv epoch number is 1 less than model file epoch. For example, epoch 79 in csv corresponds to _080.tlt
# !cat $USER_EXPERIMENT_DIR/experiment_dir_unpruned/ssd_training_log_mobilenet_v2.csv
# %set_env EPOCH=100

# %% [markdown]
# ## 4. 评估训练好的模型 <a class="anchor" id="head-4"></a>

# %%
# !tlt-evaluate ssd -e $SPECS_DIR/ssd_train_mobilenet_v2_kitti.txt \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
                  -k $KEY

# %% [markdown]
# ## 5. 模型剪枝 <a class="anchor" id="head-5"></a>
# * 设置剪枝的阈值
# * 设置选择剪枝的模型，也就是我们之前通过评估选择的那个模型
# * 设置输出路径
#
# 通常，我们需要设置‘-pth’参数来平衡模型的精度与模型的大小（或者说速度）。更高的‘-pth’数值，会让模型更小（更快的推理速度），但是也会降低模型精度。在本次实验中，作者使用的是0.5，如果精度没问题，我们可以增加‘-pth’的数值，来进一步剪枝。反之，我们则需要减小‘-pth’的数值。

# %%
#创建新的文件夹，保存剪枝后的模型
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_pruned

# %%
#开始模型剪枝
# !tlt-prune -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
           -o $USER_EXPERIMENT_DIR/experiment_dir_pruned/ssd_mobilenet_v2_pruned.tlt \
           -eq intersection \
           -pth 0.5 \
           -k $KEY

# %%
#查看剪枝后的模型
# !ls -rlt $USER_EXPERIMENT_DIR/experiment_dir_pruned/

# %% [markdown]
# ## 6. 重新训练剪枝后的模型 <a class="anchor" id="head-6"></a>
# * 模型在剪枝后需要重新训练
# * 还需要定义重新训练的参数，比如学习率等。
# * 注意：重新训练也需要比较长的时间

# %%
# 在这里我们打印出训练的超参
# 在ssd_retrain_mobilenet_v2_kitti.txt文件中我们需要定义训练设置，
# 还可以通过调整数据集来取得更好的训练效果
# !cat $SPECS_DIR/ssd_retrain_mobilenet_v2_kitti.txt

# %%
# 创建一个新的文件夹，来保存重新训练的模型
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_retrain

# %%
# 使剪之后的模型作为预训练模型，重新训练
# !tlt-train ssd --gpus 1 \
               -e $SPECS_DIR/ssd_retrain_mobilenet_v2_kitti.txt \
               -r $USER_EXPERIMENT_DIR/experiment_dir_retrain \
               -m $USER_EXPERIMENT_DIR/experiment_dir_pruned/ssd_mobilenet_v2_pruned.tlt \
               -k $KEY

# %%
# 查看最新训练出来的模型.
# !ls -rlt $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights

# %%
# 现在，您可以在.CVS文件中查看模型的评估结果
# 注意.CVS文件中的序号比实际训练的序号小1, epoch 79 模型指的是第80个.tlt
# !cat $USER_EXPERIMENT_DIR/experiment_dir_retrain/ssd_training_log_mobilenet_v2.csv
# %set_env EPOCH=040

# %% [markdown]
# ## 7. 评估预训练模型 <a class="anchor" id="head-7"></a>

# %%
# !tlt-evaluate ssd -e $SPECS_DIR/ssd_retrain_mobilenet_v2_kitti.txt \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
                  -k $KEY

# %% [markdown]
# ## 8. 可视化推理结果 <a class="anchor" id="head-8"></a>
# 在这个部分，我们利用tlt-infer在我们训练的模型的基础上进行推理，并且可视化结果

# %%
# Running inference for detection on n images
# !tlt-infer ssd -i $DATA_DOWNLOAD_DIR/infer_images \
               -o $USER_EXPERIMENT_DIR/data/infered_images \
               -e $SPECS_DIR/ssd_train_mobilenet_v2_kitti.txt \
               -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
               -l $USER_EXPERIMENT_DIR/ssd_infer_labels \
               -k $KEY

# %% [markdown]
# `tlt-infer`工具会输出两个文件
# 1. 推理检测出来的图片，保存在`$USER_EXPERIMENT_DIR/ssd_infer_images`文件夹中
# 2. 每一帧的bounding box标注文件会以KITTI的格式保存在`$USER_EXPERIMENT_DIR/ssd_infer_labels`文件夹中

# %%
# 简单的写一个可视化工具
import matplotlib.pyplot as plt
import os
from math import ceil
valid_image_ext = ['.jpg', '.png', '.jpeg', '.ppm']

def visualize_images(image_dir, num_cols=4, num_images=10):
    output_path = os.path.join(os.environ['USER_EXPERIMENT_DIR'], image_dir)
    num_rows = int(ceil(float(num_images) / float(num_cols)))
    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
    f.tight_layout()
    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
         if os.path.splitext(image)[1].lower() in valid_image_ext]
    for idx, img_path in enumerate(a[:num_images]):
        col_id = idx % num_cols
        row_id = idx / num_cols
        img = plt.imread(img_path)
        axarr[row_id, col_id].imshow(img)

# %%
# 在这里执行可视化工具
OUTPUT_PATH = "data/infered_images" # relative path from $USER_EXPERIMENT_DIR.
COLS = 4 # number of columns in the visualizer grid.
IMAGES = 12 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 9. 模型的导出和部署! <a class="anchor" id="head-9"></a>

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/export
# 这里导出的是FP32数据类型的模型，您可以通过更改--data_type的参数来更改导出的模型的数据精度
# 比如您可以设置--data_type fp16
# !tlt-export ssd -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
                -k $KEY \
                -o $USER_EXPERIMENT_DIR/export/ssd_mobilenet_v2_epoch_040.etlt \
                -e $SPECS_DIR/ssd_retrain_mobilenet_v2_kitti.txt  \
                --batch_size 1 \
                --data_type fp32

# 这里有直接导出INT 8 的数据类型的模型的命令 \
# !tlt-export ssd -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_resnet18_epoch_$EPOCH.tlt  \
#                 -o $USER_EXPERIMENT_DIR/export/ssd_resnet18_epoch_$EPOCH.etlt \
#                 -e $SPECS_DIR/ssd_retrain_resnet18_kitti.txt \
#                 -k $KEY \
#                 --cal_image_dir  $USER_EXPERIMENT_DIR/data/testing/image_2 \
#                 --data_type int8 \
#                 --batch_size 1 \
#                 --batches 10 \
#                 --cal_cache_file $USER_EXPERIMENT_DIR/export/cal.bin  \
#                 --cal_data_file $USER_EXPERIMENT_DIR/export/cal.tensorfile

# %%
# 这里展示了tlt-export所有的参数
# !tlt-export

# %%
# 这里查看导出的模型
print('导出模型:')
print('------------')
# !ls -lh $USER_EXPERIMENT_DIR/export

# %% [markdown]
# 您可以通过Docker里面自带的`tlt-converter`工具来转换模型
# `tlt-converter`工具将会将您训练出来的.etlt模型直接转换成可以部署在NVIDIA TensorRT和Deepstream 上的格式。对于x86设备，您可以直接复制docker中的工具到您自己的环境中
# 但是对于Jetson设备，您需要从下面的网址下载
# [https://developer.nvidia.com/tlt-converter](https://developer.nvidia.com/tlt-converter)

# %%
# 转换成TensorRT engine (FP32)
# !tlt-converter -k $KEY \
               -d 3,300,300 \
               -o NMS \
               -e $USER_EXPERIMENT_DIR/export/trt--mobilenet_v2_epoch_040.engine \
               -m 1 \
               -t fp32 \
               -i nchw \
               $USER_EXPERIMENT_DIR/export/ssd_mobilenet_v2_epoch_040.etlt

# Uncomment to convert to TensorRT engine (INT8).
# !tlt-converter -k $KEY  \
#                -d 3,384,1248 \
#                -o NMS \
#                -c $USER_EXPERIMENT_DIR/export/cal.bin \
#                -e $USER_EXPERIMENT_DIR/export/trt.engine \
#                -b 8 \
#                -m 1 \
#                -t int8 \
#                -i nchw \
#                $USER_EXPERIMENT_DIR/export/ssd_resnet18_epoch_$EPOCH.etlt

# %%
#查看转换好的推理引擎
print('Exported engine:')
print('------------')
# !ls -lh $USER_EXPERIMENT_DIR/export/trt*.engine

# %% [markdown]
# ## 10. 确认导出模型 <a class="anchor" id="head-10"></a>
# 通过下面的命令来确认导出的engine文件是否可以正确运行

# %%
# 使用TensorRT engine文件进行推理
# 注意这里的tlt-infer 工具只支持batchsize为1，这点非常重要. 
# 所以请确认在使用tlt-converter工具时 ,使用`-m 1 --batch_size 1`为参数


# !tlt-infer ssd --trt -p $USER_EXPERIMENT_DIR/export/trt--mobilenet_v2_epoch_040.engine \
                     -e $SPECS_DIR/ssd_train_mobilenet_v2_kitti.txt \
                     -i $DATA_DOWNLOAD_DIR/infer_images \
                     -o $USER_EXPERIMENT_DIR/ssd_infer_images \
                     -t 0.4

# %%
# !echo $KEY
